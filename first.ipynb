# %%
#my stattictics first class 
import os 
print(os.getcwd())
# Out:
# c:\Users\Shuvo\Statictics assignment

# %%
import pandas as pd 
df=pd.read_csv('yhtujgu/AirPassengers.csv')

# %%
df.head()
# Out:
#      Month  #Passengers
# 0  1949-01          112
# 1  1949-02          118
# 2  1949-03          132
# 3  1949-04          129
# 4  1949-05          121

# %%
df.describe
# Out:
# <bound method NDFrame.describe of        Month  #Passengers
# 0    1949-01          112
# 1    1949-02          118
# 2    1949-03          132
# 3    1949-04          129
# 4    1949-05          121
# ..       ...          ...
# 139  1960-08          606
# 140  1960-09          508
# 141  1960-10          461
# 142  1960-11          390
# 143  1960-12          432
#
# [144 rows x 2 columns]>

# %%
print(df.to_string())
# Out:
#        Month  #Passengers
# 0    1949-01          112
# 1    1949-02          118
# 2    1949-03          132
# 3    1949-04          129
# 4    1949-05          121
# 5    1949-06          135
# 6    1949-07          148
# 7    1949-08          148
# 8    1949-09          136
# 9    1949-10          119
# 10   1949-11          104
# 11   1949-12          118
# 12   1950-01          115
# 13   1950-02          126
# 14   1950-03          141
# 15   1950-04          135
# 16   1950-05          125
# 17   1950-06          149
# 18   1950-07          170
# 19   1950-08          170
# 20   1950-09          158
# 21   1950-10          133
# 22   1950-11          114
# 23   1950-12          140
# 24   1951-01          145
# 25   1951-02          150
# 26   1951-03          178
# 27   1951-04          163
# 28   1951-05          172
# 29   1951-06          178
# 30   1951-07          199
# 31   1951-08          199
# 32   1951-09          184
# 33   1951-10          162
# ...

# %%
import requests

url = 'https://www.kaggle.com/datasets/pattnaiksatyajit/air-passengers'
response = requests.get(url)

with open('data.csv', 'wb') as f:
    f.write(response.content)

# %%
df1=pd.read_csv('data.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df1=pd.read_csv('data.csv')
#
# NameError: name 'pd' is not defined

# %%
df.to_csv('yhtujgu/binary.csv',index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df.to_csv('yhtujgu/binary.csv',index=False)
#
# NameError: name 'df' is not defined

# %%
import pandas as pd 
flight=pd.read_csv('flight_data.csv')
flight.head()
# Out:
#    miles  passengers  delay inflight_meal inflight_entertainment  \
# 0    792         172      0            No                    Yes
# 1   3163         214      0            No                    Yes
# 2   1832         212      0            No                    Yes
# 3    925         213      0            No                    Yes
# 4    967         217      0           Yes                    Yes
#
#   inflight_wifi day_of_week redeye weekend  coach_price  firstclass_price  \
# 0           Yes      Sunday    Yes     Yes      338.820           1571.02
# 1           Yes      Sunday     No     Yes      472.655           1663.70
# 2            No      Friday     No     Yes      351.960           1429.86
# 3           Yes    Saturday     No     Yes      387.835           1558.76
# 4           Yes      Monday     No      No      374.735           1245.58
#
#    hours
# 0      1
# 1      6
# 2      3
# 3      2
# 4      2

# %%
flight.describe()
# Out:
#                miles     passengers          delay    coach_price  \
# count  129780.000000  129780.000000  129780.000000  129780.000000
# mean     2006.224696     207.723155      13.162845     376.585253
# std       943.034768      12.776363      41.941680      67.744274
# min        12.000000     135.000000       0.000000      44.415000
# 25%      1343.000000     204.000000       9.000000     331.445000
# 50%      1986.000000     210.000000      10.000000     380.560000
# 75%      2468.000000     215.000000      13.000000     426.676250
# max      4548.000000     244.000000    1560.000000     593.635000
#
#        firstclass_price          hours
# count     129780.000000  129780.000000
# mean        1454.931785       3.631214
# std          162.590434       1.739118
# min          939.100000       1.000000
# 25%         1302.200000       2.000000
# 50%         1503.840000       4.000000
# 75%         1582.370000       4.000000
# max         1846.780000       8.000000

# %%
print("Ticket price staticics")
print(flight.coach_price.describe())
# Out:
# Ticket price staticics
# count    129780.000000
# mean        376.585253
# std          67.744274
# min          44.415000
# 25%         331.445000
# 50%         380.560000
# 75%         426.676250
# max         593.635000
# Name: coach_price, dtype: float64

# %%
pd.read_csv('flight_data.csv')
# Out:
#         miles  passengers  delay inflight_meal inflight_entertainment  \
# 0         792         172      0            No                    Yes
# 1        3163         214      0            No                    Yes
# 2        1832         212      0            No                    Yes
# 3         925         213      0            No                    Yes
# 4         967         217      0           Yes                    Yes
# ...       ...         ...    ...           ...                    ...
# 129775    674         217   1487            No                    Yes
# 129776   2125         208   1479            No                    Yes
# 129777   1702         220   1501            No                    Yes
# 129778   2709         205   1484            No                    Yes
# 129779   4005         214   1490            No                    Yes
#
#        inflight_wifi day_of_week redeye weekend  coach_price  \
# 0                Yes      Sunday    Yes     Yes      338.820
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
plt.title('Boxolot of tickket price ')
sns.boxplot(flight.coach_price)
plt.xlabel('Coach price ')
plt.ylabel('Meau')
plt.show()

# %%
# %pip install stemgraphic
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13858 sha256=e252625109528cea0dba3ee1998311b3d16ad280d361d54972a8bbd134001ee2
#   Stored in directory: c:\users\shuvo\appdata\local\pip\cache\wheels\0b\1d\03\175286677fb5a1341cc3e4755bf8ec0ed08f3329afd67446b0
# Successfully built docopt
# ...
#
#    -------------------- ------------------- 1/2 [stemgraphic]
#    ---------------------------------------- 2/2 [stemgraphic]
#
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...

# %%
import stemgraphic
slp=stemgraphic.stem_graphic(flight.coach_price)

# %%
price = flight['coach_price'].value_counts()

plt.figure(figsize=(8, 6))
plt.bar(price.index, price, color='deeppink')
plt.title('Total Coach Price Count')
plt.xlabel('Coach Price')
plt.ylabel('Count')
plt.show()
